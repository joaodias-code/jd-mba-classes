# %%
import pandas as pd

# %% [markdown]
# ## Carregando os dados
#
# Vamos carregar os dados e inspecionar visualmente.
#
# Podemos aplicar um estilo no dataset que coloca um gradiente colorido na coluna, isso nos ajuda a identificar valores mais extremos de forma rápida.

# %%
vendas = pd.read_excel('Aula 03 - Atividade - Base vendas.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-de74dc7e8214> in <module>
# ----> 1 vendas = pd.read_excel('Aula 03 - Atividade - Base vendas.xlsx')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     308
#     309     if not isinstance(io, ExcelFile):
# --> 310         io = ExcelFile(io, engine=engine)
#     311     elif engine and engine != io.engine:
#     312         raise ValueError(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     817         self._io = _stringify_path(io)
#     818
# --> 819         self._reader = self._engines[engine](self._io)
#     820
#     821     def __fspath__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     357             self.book = self.load_workbook(filepath_or_buffer)
#     358         elif isinstance(filepath_or_buffer, str):
# --> 359             self.book = self.load_workbook(filepath_or_buffer)
#     360         else:
#     361             raise ValueError(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Aula 03 - Atividade - Base vendas.xlsx'

# %%
vendas.style.background_gradient(cmap='BuPu', subset=['Vendas'])
# Out:
# <style  type="text/css" >
#     #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row0_col1 {
#             background-color:  #f6fbfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row1_col1 {
#             background-color:  #f3f9fc;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row2_col1 {
#             background-color:  #f6fbfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row3_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row4_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row5_col1 {
#             background-color:  #8c7ab8;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row6_col1 {
#             background-color:  #f6fbfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row7_col1 {
#             background-color:  #e2edf5;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row8_col1 {
#             background-color:  #f6fbfc;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row9_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row10_col1 {
#             background-color:  #e5eff6;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row11_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row12_col1 {
#             background-color:  #f6fbfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row13_col1 {
#             background-color:  #e2edf5;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row14_col1 {
#             background-color:  #f6fbfc;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row15_col1 {
#             background-color:  #f6fbfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row16_col1 {
#             background-color:  #f1f8fb;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row17_col1 {
#             background-color:  #f5fafc;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row18_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row19_col1 {
#             background-color:  #dce9f2;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row20_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row21_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row22_col1 {
#             background-color:  #873d9a;
#             color:  #f1f1f1;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row23_col1 {
#             background-color:  #f6fbfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row24_col1 {
#             background-color:  #f6fbfc;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row25_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row26_col1 {
#             background-color:  #f2f8fb;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row27_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row28_col1 {
#             background-color:  #f6fbfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row29_col1 {
#             background-color:  #f6fbfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row30_col1 {
#             background-color:  #873b99;
#             color:  #f1f1f1;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row31_col1 {
#             background-color:  #edf5f9;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row32_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row33_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row34_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row35_col1 {
#             background-color:  #f2f8fb;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row36_col1 {
#             background-color:  #f5fafc;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row37_col1 {
#             background-color:  #4d004b;
#             color:  #f1f1f1;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row38_col1 {
#             background-color:  #f1f7fa;
#             color:  #000000;
#         }    #T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row39_col1 {
#             background-color:  #dce9f2;
#             color:  #000000;
#         }</style><table id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Dia</th>        <th class="col_heading level0 col1" >Vendas</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row0_col1" class="data row0 col1" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row1_col1" class="data row1 col1" >16</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row2_col1" class="data row2 col1" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row3_col1" class="data row3 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row4_col1" class="data row4 col1" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_0d2cdb0a_7d36_11ea_ab50_dca904912be9row5_col1" class="data row5 col1" >178</td>
#             </tr>
#             <tr>
#                         <th id="T_0d2cdb0a_7d36_11ea_ab5

# %% [markdown]
# ## Z-Score

# %%
from scipy import stats

# %%
zscores = stats.zscore(vendas['Vendas'],ddof=1)

# %%
zscores
# Out:
# array([-0.39961159, -0.34116748, -0.39961159, -0.42883364, -0.41422261,
#         2.02581888, -0.39961159,  0.05333025, -0.38500056, -0.42883364,
#        -0.00511386, -0.41422261, -0.39961159,  0.05333025, -0.38500056,
#        -0.39961159, -0.28272337, -0.37038953, -0.42883364,  0.17021846,
#        -0.42883364, -0.42883364,  2.78559228, -0.39961159, -0.38500056,
#        -0.41422261, -0.31194542, -0.42883364, -0.39961159, -0.39961159,
#         2.81481433, -0.19505721, -0.42883364, -0.41422261, -0.42883364,
#        -0.2973344 , -0.37038953,  3.80836416, -0.26811234,  0.17021846])

# %% [markdown]
# ### Aplicando o limite para identificar os outliers

# %%
zscores[zscores > 3]
# Out:
# array([3.80836416])

# %% [markdown]
# #### Encontrando a posição do outlier identificado

# %%
import numpy as np

# %%
np.where(zscores > 3)
# Out:
# (array([37]),)

# %% [markdown]
# #### Visualizando o outlier encontrado

# %%
vendas.loc[[37]]
# Out:
#     Dia  Vendas
# 37   38     300

# %% [markdown]
# ### Atenção
#
# Observamos que o Z-Score capturou apenas um outlier: o valor 300, que é o mais extremo. Isso mostra como esse método é sensível à valores extremos.
#
# Se diminuírmos o nosso limite, conseguiremos identificar os outros

# %%
vendas.loc[np.where((zscores > 1.96) | (zscores < -1.96))]
# Out:
#     Dia  Vendas
# 5     6     178
# 22   23     230
# 30   31     232
# 37   38     300

# %% [markdown]
# ## Cumulative Distribution

# %%
stats.norm.cdf(-1.96)
# Out:
# 0.024997895148220435

# %%
stats.norm.ppf(0.01)
# Out:
# -2.3263478740408408

# %%
stats.norm.ppf(0.99)
# Out:
# 2.3263478740408408

# %% [markdown]
# ## Modified Z-Score

# %%
def m_zscore(lista):
    mediana = np.median(lista)
    mad = np.median([np.abs(y - mediana) for y in lista])
    
    valores = []
    for valor in lista:
        score = 0.6745 * (valor - mediana) / mad
        valores.append(score)
    
    return valores

# %% [markdown]
# ### Visualizando os outliers identificados
#
# Na lista abaixo conseguimos visualizar os scores acima / abaixo do limite e o índice deles.
#
# Mais abaixo temos os valores encontrados no dataframe

# %%
m_scores = m_zscore(vendas['Vendas'])

# %%
[[i, x] for i, x in enumerate(m_scores) if (x > 3) | ( x < -3)]
# Out:
# [[5, 44.6519],
#  [7, 8.2289],
#  [10, 7.1497],
#  [13, 8.2289],
#  [19, 10.3873],
#  [22, 58.68149999999999],
#  [30, 59.2211],
#  [31, 3.6423],
#  [37, 77.5675],
#  [39, 10.3873]]

# %%
vendas.loc[[i for i, x in enumerate(m_scores) if (x > 3) | ( x < -3)]]
# Out:
#     Dia  Vendas
# 5     6     178
# 7     8      43
# 10   11      39
# 13   14      43
# 19   20      51
# 22   23     230
# 30   31     232
# 31   32      26
# 37   38     300
# 39   40      51

# %% [markdown]
# ### Atenção
#
# Observamos que o Z-Score modificado é, por outro lado, bem menos sensível a valores extremos que o Z-Score "normal" (baseado na média). Ele capturou uma grande quantidade de outliers, alguns que podemos considerar "duvidosos", o que torna esse método bem mais agressivo.

# %% [markdown]
# ## Média Móvel

# %%
vendas[0:7]
# Out:
#    Dia  Vendas
# 0    1      12
# 1    2      16
# 2    3      12
# 3    4      10
# 4    5      11
# 5    6     178
# 6    7      12

# %%
vendas['MM'] = vendas.Vendas.rolling(7,center=False).mean() 
vendas.head(15)
# Out:
#     Dia  Vendas         MM
# 0     1      12        NaN
# 1     2      16        NaN
# 2     3      12        NaN
# 3     4      10        NaN
# 4     5      11        NaN
# 5     6     178        NaN
# 6     7      12  35.857143
# 7     8      43  40.285714
# 8     9      13  39.857143
# 9    10      10  39.571429
# 10   11      39  43.714286
# 11   12      11  43.714286
# 12   13      12  20.000000
# 13   14      43  24.428571
# 14   15      13  20.142857

# %%
vendas['ResiduoMM'] = abs(vendas.Vendas - vendas.MM)
vendas['ToleranciaMM'] = vendas.MM * 0.5
vendas.head(15)
# Out:
#     Dia  Vendas         MM  ResiduoMM  ToleranciaMM
# 0     1      12        NaN        NaN           NaN
# 1     2      16        NaN        NaN           NaN
# 2     3      12        NaN        NaN           NaN
# 3     4      10        NaN        NaN           NaN
# 4     5      11        NaN        NaN           NaN
# 5     6     178        NaN        NaN           NaN
# 6     7      12  35.857143  23.857143     17.928571
# 7     8      43  40.285714   2.714286     20.142857
# 8     9      13  39.857143  26.857143     19.928571
# 9    10      10  39.571429  29.571429     19.785714
# 10   11      39  43.714286   4.714286     21.857143
# 11   12      11  43.714286  32.714286     21.857143
# 12   13      12  20.000000   8.000000     10.000000
# 13   14      43  24.428571  18.571429     12.214286
# 14   15      13  20.142857   7.142857     10.071429

# %%
vendas['OutlierMM'] = (vendas.ResiduoMM > vendas.ToleranciaMM)
vendas.head(15)
# Out:
#     Dia  Vendas         MM  ResiduoMM  ToleranciaMM  OutlierMM
# 0     1      12        NaN        NaN           NaN      False
# 1     2      16        NaN        NaN           NaN      False
# 2     3      12        NaN        NaN           NaN      False
# 3     4      10        NaN        NaN           NaN      False
# 4     5      11        NaN        NaN           NaN      False
# 5     6     178        NaN        NaN           NaN      False
# 6     7      12  35.857143  23.857143     17.928571       True
# 7     8      43  40.285714   2.714286     20.142857      False
# 8     9      13  39.857143  26.857143     19.928571       True
# 9    10      10  39.571429  29.571429     19.785714       True
# 10   11      39  43.714286   4.714286     21.857143      False
# 11   12      11  43.714286  32.714286     21.857143       True
# 12   13      12  20.000000   8.000000     10.000000      False
# 13   14      43  24.428571  18.571429     12.214286       True
# 14   15      13  20.142857   7.142857     10.071429      False

# %% [markdown]
# ### Visualizando o resultado

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.style.use('seaborn')

# %%
_=vendas.Vendas.plot(figsize=(20, 10))
_=vendas.MM.plot(figsize=(20, 10), color='red', style='--')
plt.fill_between(vendas.index, vendas.MM-vendas.ToleranciaMM, vendas.MM+vendas.ToleranciaMM, alpha=0.2)
plt.plot()
# Out:
# []

# %% [markdown]
# ### Atenção
#
# Observamos que agora um ponto é considerado outlier baseado no comportamento da série em uma janela móvel, e não apenas nos números da série por si.

# %% [markdown]
# # Mediana Móvel

# %%
vendas['MedM'] = vendas.Vendas.rolling(7,center=False).median()
vendas.head(15)
# Out:
#     Dia  Vendas         MM  ResiduoMM  ToleranciaMM  OutlierMM  MedM
# 0     1      12        NaN        NaN           NaN      False   NaN
# 1     2      16        NaN        NaN           NaN      False   NaN
# 2     3      12        NaN        NaN           NaN      False   NaN
# 3     4      10        NaN        NaN           NaN      False   NaN
# 4     5      11        NaN        NaN           NaN      False   NaN
# 5     6     178        NaN        NaN           NaN      False   NaN
# 6     7      12  35.857143  23.857143     17.928571       True  12.0
# 7     8      43  40.285714   2.714286     20.142857      False  12.0
# 8     9      13  39.857143  26.857143     19.928571       True  12.0
# 9    10      10  39.571429  29.571429     19.785714       True  12.0
# 10   11      39  43.714286   4.714286     21.857143      False  13.0
# 11   12      11  43.714286  32.714286     21.857143       True  13.0
# 12   13      12  20.000000   8.000000     10.000000      False  12.0
# 13   14      43  24.428571  18.571429     12.214286       True  13.0
# 14   15      13  20.142857   7.142857     10.071429      False  13.0

# %%
vendas['ResiduoMedM'] = abs(vendas.Vendas - vendas.MedM)
vendas['ToleranciaMedM'] = vendas.MedM * 0.5
vendas.head(15)
# Out:
#     Dia  Vendas         MM  ResiduoMM  ToleranciaMM  OutlierMM  MedM  \
# 0     1      12        NaN        NaN           NaN      False   NaN
# 1     2      16        NaN        NaN           NaN      False   NaN
# 2     3      12        NaN        NaN           NaN      False   NaN
# 3     4      10        NaN        NaN           NaN      False   NaN
# 4     5      11        NaN        NaN           NaN      False   NaN
# 5     6     178        NaN        NaN           NaN      False   NaN
# 6     7      12  35.857143  23.857143     17.928571       True  12.0
# 7     8      43  40.285714   2.714286     20.142857      False  12.0
# 8     9      13  39.857143  26.857143     19.928571       True  12.0
# 9    10      10  39.571429  29.571429     19.785714       True  12.0
# 10   11      39  43.714286   4.714286     21.857143      False  13.0
# 11   12      11  43.714286  32.714286     21.857143       True  13.0
# 12   13      12  20.000000   8.000000     10.000000      False  12.0
# 13   14      43  24.428571  18.571429     12.214286       True  13.0
# 14   15      13  20.142857   7.142857     10.071429      False  13.0
#
#     ResiduoMedM  ToleranciaMedM
# 0           NaN             NaN
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN
# 5           NaN             NaN
# 6           0.0             6.0
# 7          31.0             6.0
# 8           1.0             6.0
# 9           2.0             6.0
# 10         26.0             6.5
# 11          2.0             6.5
# 12          0.0             6.0
# 13         30.0             6.5
# 14          0.0             6.5

# %%
vendas['OutlierMedM'] = (vendas.ResiduoMedM > vendas.ToleranciaMedM)
vendas.head(15)
# Out:
#     Dia  Vendas         MM  ResiduoMM  ToleranciaMM  OutlierMM  MedM  \
# 0     1      12        NaN        NaN           NaN      False   NaN
# 1     2      16        NaN        NaN           NaN      False   NaN
# 2     3      12        NaN        NaN           NaN      False   NaN
# 3     4      10        NaN        NaN           NaN      False   NaN
# 4     5      11        NaN        NaN           NaN      False   NaN
# 5     6     178        NaN        NaN           NaN      False   NaN
# 6     7      12  35.857143  23.857143     17.928571       True  12.0
# 7     8      43  40.285714   2.714286     20.142857      False  12.0
# 8     9      13  39.857143  26.857143     19.928571       True  12.0
# 9    10      10  39.571429  29.571429     19.785714       True  12.0
# 10   11      39  43.714286   4.714286     21.857143      False  13.0
# 11   12      11  43.714286  32.714286     21.857143       True  13.0
# 12   13      12  20.000000   8.000000     10.000000      False  12.0
# 13   14      43  24.428571  18.571429     12.214286       True  13.0
# 14   15      13  20.142857   7.142857     10.071429      False  13.0
#
#     ResiduoMedM  ToleranciaMedM  OutlierMedM
# 0           NaN             NaN        False
# 1           NaN             NaN        False
# 2           NaN             NaN        False
# 3           NaN             NaN        False
# 4           NaN             NaN        False
# 5           NaN             NaN        False
# 6           0.0             6.0        False
# 7          31.0             6.0         True
# 8           1.0             6.0        False
# 9           2.0             6.0        False
# 10         26.0             6.5         True
# 11          2.0             6.5        False
# 12          0.0             6.0        False
# 13         30.0             6.5         True
# 14          0.0             6.5        False

# %% [markdown]
# ### Visualizando o resultado

# %%
_=vendas.Vendas.plot(figsize=(20, 10))
_=vendas.MedM.plot(figsize=(20, 10), color='red', style='--')
plt.fill_between(vendas.index, vendas.MedM-vendas.ToleranciaMedM, vendas.MedM+vendas.ToleranciaMedM, alpha=0.2)
plt.plot()
# Out:
# []

# %% [markdown]
# ### Atenção
#
# Observamos que apesar de continuar baseado no comportamento da série, a mediana está penalizando muito mais os picos de variação.
